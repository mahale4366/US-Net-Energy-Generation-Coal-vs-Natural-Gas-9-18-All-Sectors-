# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel(r'C:\Users\matth\Documents\Excel EIA Energy\EIAFL.xlsx', sheet_name='5. Generation')
df1 = df.Total_electric_industry/1000000
df1.index = df1.index + 1990
y_pos = np.arange(1990,2018.25)
plt.plot(df1, color='red', label='Total Electricity Generation',linewidth=2.5)
plt.xlim(1989.75,2018.25)

plt.xticks(y_pos,rotation=60)
plt.xlabel('Year')
plt.ylabel('Million Megawatt Hours')
plt.title('US Total Electricity Generation: 1990-2018')
plt.legend()
plt.axvline(x=1992, color='black',linewidth=.5)
plt.axvline(x=2000, color='black',linewidth=.5)
plt.axvline(x=2008, color='black',linewidth=.5)
plt.axvline(x=2016, color='black',linewidth=.5)
x = np.arange(1989.75,2018)
y1 = [131.502551,
 139.41669,
 143.777142,
 151.934155,
 158.146848,
 167.414374,
 167.084937,
 168.246994,
 189.628995,
 187.263424,
 191.815839,
 190.945341,
 203.352775,
 212.610011,
 218.117928,
 220.256412,
 223.751621,
 225.41606,
 219.636818,
 217.952308,
 229.095935,
 221.894574,
 221.096136,
 222.398924,
 230.015937,
 237.412633,
 238.26215,
 238.413149,
 244.25201]
plt.fill_between(x,y1, 0, color='red')   
plt.show()
