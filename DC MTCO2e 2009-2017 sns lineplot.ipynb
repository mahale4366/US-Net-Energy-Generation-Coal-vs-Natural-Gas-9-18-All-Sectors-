# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly
import cufflinks as cf
cf.go_offline()
import datetime
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_excel(r'C:\Users\matth\Documents\DC GHG\2006-2017 DCGHG.xlsx', sheet_name='Sheet1')
df
# Out:
#     Year         Type  Consumption  MTCO2e         Units
# 0   2006  Electricity    500858750  260100           KWh
# 1   2009  Electricity    447761150  193390           KWh
# 2   2010  Electricity    477647800  218080           KWh
# 3   2011  Electricity    485021850  221450           KWh
# 4   2012  Electricity    522951180  184880           KWh
# 5   2013  Electricity    529539420  217760           KWh
# 6   2014  Electricity    493365100  199310           KWh
# 7   2015  Electricity    556732350  210730           KWh
# 8   2016  Electricity    556402500  192310           KWh
# 9   2017  Electricity    526221670  181880           KWh
# 10  2006          Gas     21460220  114140        Therms
# 11  2009          Gas     23165480  123210        Therms
# 12  2010          Gas     18273680   97200        Therms
# 13  2011          Gas     11947790   78940        Therms
# 14  2012          Gas     11880040   66230        Therms
# ...

# %%
df['Year'].astype(str)
# Out:
# 0     2006
# 1     2009
# 2     2010
# 3     2011
# 4     2012
# 5     2013
# 6     2014
# 7     2015
# 8     2016
# 9     2017
# 10    2006
# 11    2009
# 12    2010
# 13    2011
# 14    2012
# 15    2013
# 16    2014
# 17    2015
# 18    2016
# 19    2017
# 20    2006
# 21    2009
# 22    2010
# 23    2011
# 24    2012
# 25    2013
# 26    2014
# 27    2015
# 28    2016
# 29    2017
# 30    2006
# 31    2009
# 32    2010
# 33    2011
# 34    2012
# 35    2013
# 36    2014
# 37    2015
# 38    2016
# 39    2017
# 40    2006
# 41    2009
# 42    2010
# 43    2011
# 44    2012
# 45    2013
# 46    2014
# 47    2015
# 48    2016
# 49    2017
# Name: Year, dtype: object

# %%
sns.lineplot(x='Year',y='MTCO2e',data=df,hue='Type', palette='Set1')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('DC Mega Tons CO2 Emitted by Source (2009-2017)')
plt.show()
